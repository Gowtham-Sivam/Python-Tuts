# %% [markdown]
# ### Random

# %% [markdown]
# - Random means something that can not be predicted logically.

# %% [markdown]
# ##### Pseudo Random vs Truly Random
# - **Pseudo Random** - Function that generates random numbers, which means there is a **logic to generate** random numbers.
# - **Truly Random**  - Based random data from outside like based on **mouse click, random data from network**. (we dont need it unless its for security)

# %%
# Install Numpy
# !pip install Numpy

# %%
import numpy as np

# %%
# Generate a Random Number
a = random.randint(100)

print(a)

x = random.rand() # float between 0 to 1 

print(x)
# Out:
# 79
# 0.1299765983597022

# %%
# 5 numbers from the array
x=random.randint(100, size=(5))

print(x)
# Out:
# [ 6 21 21 22  0]

# %%
# 2D Array of 3 rows & 5 Cols
x = random.randint(100, size=(3, 5)) 

print(x)
# Out:
# [[10 94  1 57 42]
#  [32 38 38 88 93]
#  [99 45 30 67 81]]

# %%
#choice
x = random.choice([3, 5, 7, 9])

print(x)
# Out:
# 5

# %%
# 2D Array with follwing values of specific size
x = random.choice([3, 5, 7, 9], size=(3, 5))

print(x)
# Out:
# [[7 3 9 9 3]
#  [7 9 5 7 9]
#  [7 5 5 7 9]]

# %% [markdown]
# ### Random Data Distribution

# %%
# 1-D array containing 100 values, where each value has to be 1, 2, 17 or 186. 
# sum of all probability numbers should be 1
from numpy import random

x = random.choice([1, 2, 17,186], p=[0.1, 0.3, 0.6, 0.0], size=(100))
print("Generated numbers : ")
print(x, "\n")

print("Count of the Occurrence of the Number: ")
# Count the occurrence
from collections import Counter
Counter(x)
# Out:
# Generated numbers :
# [17 17  1 17  1  2  1 17 17 17  2 17  2  2 17 17  2  1  1 17  2 17  2 17
#  17 17 17 17  2 17 17 17  2 17  2 17  2 17  2  2  2  2 17  2 17  2  2 17
#  17  1 17  2 17 17 17  1 17  2  2 17 17 17  2 17  2 17 17 17 17 17  2  2
#   2  1  2 17  1  2 17 17 17  2  2 17  1  2 17  2 17  2 17  2 17  1 17 17
#  17  2  2 17]
#
# Count of the Occurrence of the Number:
# Counter({17: 53, 2: 36, 1: 11})

# %%
#### Permute / Shuffle
# Shuffle() - Makes changes to original Array
# Permute() - Re-arranged array (and leaves the original array un-changed).
arr = np.array([1, 2, 3, 4, 5])

random.shuffle(arr)

print(arr)
# Out:
# [5 1 2 3 4]

# %%
arr = np.array([1, 2, 3, 4, 5])

print(random.permutation(arr))
# Out:
# [5 2 3 1 4]

# %%
# !pip install seaborn
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# A histogram is a graph that displays the frequency of numerical data using rectangles
# with histogram
sns.distplot([0, 1, 2, 3, 4, 5])

plt.show()
# Out:
# C:\Users\Gowtham\AppData\Local\Temp\ipykernel_11240\3490525831.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5])

# %%
#without histogram
sns.distplot([0, 1, 2, 3, 4, 5], hist=False)

plt.show()
# Out:
# C:\Users\Gowtham\AppData\Local\Temp\ipykernel_11240\1074436991.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5], hist=False)

# %% [markdown]
# **Normal / Gaussian Distribution**
#
# It's characterized by a **bell-shaped curve** where most values cluster around the **mean** (average), and the further away you move from the mean, the fewer values you encounter.
#
# Imagine you're measuring the heights of students in a classroom. If most students are around the average height, with only a few being significantly taller or shorter, their heights would follow a **Gaussian distribution**.
#
# It's a handy mathematical model for describing how data is spread out around a central value.

# %%
#random normal distribution of size 2x3
x = random.normal(size=(2, 3))
print(x)
# loc - (Mean) where the peak of the bell exists.
# scale - (Standard Deviation) how flat the graph distribution should be.
x = random.normal(loc=1, scale=2, size=(2, 3))

print(x)
# Out:
# [[ 0.0269641   0.22986436 -1.84223112]
#  [-0.88704373 -1.11509491 -0.04779014]]
# [[ 3.25585948  1.17750263  2.01779589]
#  [ 0.70086977  2.25793164 -2.34035803]]

# %% [markdown]
# **Discrete Distribution vs Continuous Distribution**
# - **Discrete Distribution** - Represents probabilities of outcomes in a finite or countably infinite set of possible values.
# - Examples include rolling a die, counting occurrences of words in a text, or recording the number of defects in a batch of products.
# - Possible outcomes: {1, 2, 3, 4, 5, 6} of Rolling a Dice
#
# - **Continuous Distribution** - Represents probabilities of outcomes in a continuous range of values.
# -   Can take any value within a given interval.
# -   Examples include measuring heights or weights of individuals, recording reaction times, or estimating temperatures.

# %% [markdown]
# **Binomial Distribution:**
# - Discrete Distrubition
# - outcome of binary scenarios, e.g. toss of a coin, it will either be head or tails.

# %%
# n - number of trials.
# p - probability of occurence of each trial (e.g. for toss of a coin 0.5 each).
# size - The shape of the returned array.

x = random.binomial(n=10, p=0.5, size=10)

print(x)
# Out:
# [5 4 5 2 5 5 4 5 6 5]

# %%
sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)

plt.show()
# Out:
# C:\Users\Gowtham\AppData\Local\Temp\ipykernel_11240\661670757.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)

# %%
# Normal vs Binomial
# if there are enough data points it will be quite similar to normal distribution with certain loc and scale.
sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')
sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist=False, label='binomial')

plt.show()
# Out:
# C:\Users\Gowtham\AppData\Local\Temp\ipykernel_11240\3334510217.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')
# C:\Users\Gowtham\AppData\Local\Temp\ipykernel_11240\3334510217.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist=False, label='binomial')
